# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.16.1

# %%
# !pip install tensorflow==2.16.1
# Out:
# Requirement already satisfied: tensorflow==2.16.1 in /usr/local/lib/python3.10/dist-packages (2.16.1)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.16.1) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.16.1) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.16.1) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.16.1) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.16.1) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.16.1) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.16.1) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.3.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.16.1) (0.3.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.16.1) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.16.1) (24.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.16.1) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.16.1) (2.31.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.16.1) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.16.1) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.16.1) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.16.1) (4.11.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.16.1) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.16.1) (1.62.1)
# Requirement already satisfied: tensorboard<2.17,>=2.16 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.16.1) (2.16.2)
# Requirement already satisfied: keras>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.16.1) (3.2.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.16.1) (0.36.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.16.1) (1.25.2)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow==2.16.1) (0.43.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras>=3.0.0->tensorflow==2.16.1) (13.7.1)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras>=3.0.0->tensorflow==2.16.1) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras>=3.0.0->tensorflow==2.16.1) (0.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow==2.16.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow==2.16.1) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow==2.16.1) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow==2.16.1) (2024.2.2)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.17,>=2.16->tensorflow==2.16.1) (3.6)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.17,>=2.16->tensorflow==2.16.1) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.17,>=2.16->tensorflow==2.16.1) (3.0.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.17,>=2.16->tensorflow==2.16.1) (2.1.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.0.0->tensorflow==2.16.1) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.0.0->tensorflow==2.16.1) (2.16.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.0.0->tensorflow==2.16.1) (0.1.2)

# %%
import os
import shutil
import cv2
import math
import random
import numpy as np
import tensorflow as tf
from tensorflow import keras
from collections import deque
import matplotlib.pyplot as plt
plt.style.use("seaborn")

# %matplotlib inline

from sklearn.model_selection import train_test_split

from keras.layers import *
from keras.models import Sequential
from keras.utils import to_categorical
from keras.callbacks import EarlyStopping
from keras.utils import plot_model
from keras.applications.mobilenet_v2 import MobileNetV2

from IPython.display import HTML
from base64 import b64encode
# Out:
# <ipython-input-3-cba350514c4c>:11: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use("seaborn")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip "/content/drive/MyDrive/violence.zip" -d "/content/datasets/"
# Out:
# Archive:  /content/drive/MyDrive/violence.zip
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_1.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_10.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_100.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_1000.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_101.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_102.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_103.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_104.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_105.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_106.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_107.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_108.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_109.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_11.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_110.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_111.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_112.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_113.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_114.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_115.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_116.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_117.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_118.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_119.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_12.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_120.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_121.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_122.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_123.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_124.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_125.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_126.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_127.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_128.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_129.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_13.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_130.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_131.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_132.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_133.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_134.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_135.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_136.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_137.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_138.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_139.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_14.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_140.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_141.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_142.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_143.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_144.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_145.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_146.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_147.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_148.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_149.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_15.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_150.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_151.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_152.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_153.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_154.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_155.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_156.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_157.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_158.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_159.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_16.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_160.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_161.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_162.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_163.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_164.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_165.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_166.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_167.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_168.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_169.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_17.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_170.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_171.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_172.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_173.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_174.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_175.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_176.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_177.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_178.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_179.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_18.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_180.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_181.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_182.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_183.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_184.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_185.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_186.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_187.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_188.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_189.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_19.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_190.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_191.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_192.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_193.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_194.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_195.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_196.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_197.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_198.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_199.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_2.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_20.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_200.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_201.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_202.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_203.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_204.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_205.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_206.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_207.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_208.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_209.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_21.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_210.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_211.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_212.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_213.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_214.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_215.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_216.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_217.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_218.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_219.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_22.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_220.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_221.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_222.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_223.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_224.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_225.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_226.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_227.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_228.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_229.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_23.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_230.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_231.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_232.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_233.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_234.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_235.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_236.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_237.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_238.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_239.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_24.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_240.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_241.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_242.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_243.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_244.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_245.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_246.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_247.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_248.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_249.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_25.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_250.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_251.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_252.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_253.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_254.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_255.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_256.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_257.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_258.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_259.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_26.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_260.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_261.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_262.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_263.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_264.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_265.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_266.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_267.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_268.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_269.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_27.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_270.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_271.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_272.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_273.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_274.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_275.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_276.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_277.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_278.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_279.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_28.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_280.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_281.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_282.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_283.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_284.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_285.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_286.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_287.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_288.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_289.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_29.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_290.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_291.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_292.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_293.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_294.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_295.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_296.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_297.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_298.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_299.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_3.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_30.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_300.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_301.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_302.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_303.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_304.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_305.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_306.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_307.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_308.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_309.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_31.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_310.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_311.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_312.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_313.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_314.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_315.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_316.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_317.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_318.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_319.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_32.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_320.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_321.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_322.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_323.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_324.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_325.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_326.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_327.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_328.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_329.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_33.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_330.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_331.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_332.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_333.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_334.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_335.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_336.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_337.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_338.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_339.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_34.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_340.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_341.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_342.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_343.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_344.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_345.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_346.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_347.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_348.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_349.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_35.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_350.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_351.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_352.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_353.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_354.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_355.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_356.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_357.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_358.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_359.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_36.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_360.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_361.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV_362.mp4
#   inflating: /content/datasets/Real Life Violence Dataset/NonViolence/NV
mp4
#   inflating: /content/datasets/real life violence situations/Real Life Violence Dataset/Violence/V_943.mp4
#   inflating: /content/datasets/real life violence situations/Real Life Violence Dataset/Violence/V_944.mp4
#   inflating: /content/datasets/real life violence situations/Real Life Violence Dataset/Violence/V_945.mp4
#   inflating: /content/datasets/real life violence situations/Real Life Violence Dataset/Violence/V_946.mp4
#   inflating: /content/datasets/real life violence situations/Real Life Violence Dataset/Violence/V_947.mp4
#   inflating: /content/datasets/real life violence situations/Real Life Violence Dataset/Violence/V_948.mp4
#   inflating: /content/datasets/real life violence situations/Real Life Violence Dataset/Violence/V_949.mp4
#   inflating: /content/datasets/real life violence situations/Real Life Violence Dataset/Violence/V_95.mp4
#   inflating: /content/datasets/real life violence situations/Real Life Violence Dataset/Violence/V_950.mp4
#   inflating: /content/datasets/real life violence situations/Real Life Violence Dataset/Violence/V_951.mp4
#   inflating: /content/datasets/real life violence situations/Real Life Violence Dataset/Violence/V_952.mp4
#   inflating: /content/datasets/real life violence situations/Real Life Violence Dataset/Violence/V_953.mp4
#   inflating: /content/datasets/real life violence situations/Real Life Violence Dataset/Violence/V_954.mp4
#   inflating: /content/datasets/real life violence situations/Real Life Violence Dataset/Violence/V_955.mp4
#   inflating: /content/datasets/real life violence situations/Real Life Violence Dataset/Violence/V_956.mp4
#   inflating: /content/datasets/real life violence situations/Real Life Violence Dataset/Violence/V_957.mp4
#   inflating: /content/datasets/real life violence situations/Real Life Violence Dataset/Violence/V_958.mp4
#   inflating: /content/datasets/real life violence situations/Real Life Violence Dataset/Violence/V_959.mp4
#   inflating: /content/datasets/real life violence situations/Real Life Violence Dataset/Violence/V_96.mp4
#   inflating: /content/datasets/real life violence situations/Real Life Violence Dataset/Violence/V_960.mp4
#   inflating: /content/datasets/real life violence situations/Real Life Violence Dataset/Violence/V_961.mp4
#   inflating: /content/datasets/real life violence situations/Real Life Violence Dataset/Violence/V_962.mp4
#   inflating: /content/datasets/real life violence situations/Real Life Violence Dataset/Violence/V_963.mp4
#   inflating: /content/datasets/real life violence situations/Real Life Violence Dataset/Violence/V_964.mp4
#   inflating: /content/datasets/real life violence situations/Real Life Violence Dataset/Violence/V_965.mp4
#   inflating: /content/datasets/real life violence situations/Real Life Violence Dataset/Violence/V_966.mp4
#   inflating: /content/datasets/real life violence situations/Real Life Violence Dataset/Violence/V_967.mp4
#   inflating: /content/datasets/real life violence situations/Real Life Violence Dataset/Violence/V_968.mp4
#   inflating: /content/datasets/real life violence situations/Real Life Violence Dataset/Violence/V_969.mp4
#   inflating: /content/datasets/real life violence situations/Real Life Violence Dataset/Violence/V_97.mp4
#   inflating: /content/datasets/real life violence situations/Real Life Violence Dataset/Violence/V_970.mp4
#   inflating: /content/datasets/real life violence situations/Real Life Violence Dataset/Violence/V_971.mp4
#   inflating: /content/datasets/real life violence situations/Real Life Violence Dataset/Violence/V_972.mp4
#   inflating: /content/datasets/real life violence situations/Real Life Violence Dataset/Violence/V_973.mp4
#   inflating: /content/datasets/real life violence situations/Real Life Violence Dataset/Violence/V_974.mp4
#   inflating: /content/datasets/real life violence situations/Real Life Violence Dataset/Violence/V_975.mp4
#   inflating: /content/datasets/real life violence situations/Real Life Violence Dataset/Violence/V_976.mp4
#   inflating: /content/datasets/real life violence situations/Real Life Violence Dataset/Violence/V_977.mp4
#   inflating: /content/datasets/real life violence situations/Real Life Violence Dataset/Violence/V_978.mp4
#   inflating: /content/datasets/real life violence situations/Real Life Violence Dataset/Violence/V_979.mp4
#   inflating: /content/datasets/real life violence situations/Real Life Violence Dataset/Violence/V_98.mp4
#   inflating: /content/datasets/real life violence situations/Real Life Violence Dataset/Violence/V_980.mp4
#   inflating: /content/datasets/real life violence situations/Real Life Violence Dataset/Violence/V_981.mp4
#   inflating: /content/datasets/real life violence situations/Real Life Violence Dataset/Violence/V_982.mp4
#   inflating: /content/datasets/real life violence situations/Real Life Violence Dataset/Violence/V_983.mp4
#   inflating: /content/datasets/real life violence situations/Real Life Violence Dataset/Violence/V_984.mp4
#   inflating: /content/datasets/real life violence situations/Real Life Violence Dataset/Violence/V_985.mp4
#   inflating: /content/datasets/real life violence situations/Real Life Violence Dataset/Violence/V_986.mp4
#   inflating: /content/datasets/real life violence situations/Real Life Violence Dataset/Violence/V_987.mp4
#   inflating: /content/datasets/real life violence situations/Real Life Violence Dataset/Violence/V_988.mp4
#   inflating: /content/datasets/real life violence situations/Real Life Violence Dataset/Violence/V_989.mp4
#   inflating: /content/datasets/real life violence situations/Real Life Violence Dataset/Violence/V_99.mp4
#   inflating: /content/datasets/real life violence situations/Real Life Violence Dataset/Violence/V_990.mp4
#   inflating: /content/datasets/real life violence situations/Real Life Violence Dataset/Violence/V_991.mp4
#   inflating: /content/datasets/real life violence situations/Real Life Violence Dataset/Violence/V_992.mp4
#   inflating: /content/datasets/real life violence situations/Real Life Violence Dataset/Violence/V_993.mp4
#   inflating: /content/datasets/real life violence situations/Real Life Violence Dataset/Violence/V_994.mp4
#   inflating: /content/datasets/real life violence situations/Real Life Violence Dataset/Violence/V_995.mp4
#   inflating: /content/datasets/real life violence situations/Real Life Violence Dataset/Violence/V_996.mp4
#   inflating: /content/datasets/real life violence situations/Real Life Violence Dataset/Violence/V_997.mp4
#   inflating: /content/datasets/real life violence situations/Real Life Violence Dataset/Violence/V_998.mp4
#   inflating: /content/datasets/real life violence situations/Real Life Violence Dataset/Violence/V_999.mp4

# %% [markdown]
# visualisation of the data

# %%
def Play_Video(filepath):
    html = ''
    video = open(filepath, 'rb').read()
    src = 'data:video/mp4;base64,' + b64encode(video).decode()
    html += '<video width=640 muted controls autoplay loop><source src="%s" type="video/mp4"></video>' % src
    return HTML(html)

# %%
# Classes Directories
NonViolnceVideos_Dir = "/content/datasets/Real Life Violence Dataset/NonViolence/"
ViolnceVideos_Dir = "/content/datasets/Real Life Violence Dataset/Violence/"

# Retrieve the list of all the video files present in the Class Directory.
NonViolence_files_names_list = os.listdir(NonViolnceVideos_Dir)
Violence_files_names_list = os.listdir(ViolnceVideos_Dir)

# Randomly select a video file from the Classes Directory.
Random_NonViolence_Video = random.choice(NonViolence_files_names_list)
Random_Violence_Video = random.choice(Violence_files_names_list)

# %%
# non violence vid
Play_Video(f"{NonViolnceVideos_Dir}/{Random_NonViolence_Video}")
# Out:
# <video width=640 muted controls autoplay loop><source src="data:video/mp4;base64,..." type="video/mp4"></video>

# %%
# violence random video
Play_Video(f"{ViolnceVideos_Dir}/{Random_Violence_Video}")
# Out:
# <video width=640 muted controls autoplay loop><source src="data:video/mp4;base64,..." type="video/mp4"></video>

# %% [markdown]
# extracting frames

# %%
# Specify the height and width to which each video frame will be resized in our dataset.
IMAGE_HEIGHT , IMAGE_WIDTH = 64, 64

# Specify the number of frames of a video that will be fed to the model as one sequence.
SEQUENCE_LENGTH = 16


DATASET_DIR = "/content/datasets/Real Life Violence Dataset/"

CLASSES_LIST = ["NonViolence","Violence"]

# %%
def frames_extraction(video_path):

    frames_list = []

    # Read the Video File
    video_reader = cv2.VideoCapture(video_path)

    # Get the total number of frames in the video.
    video_frames_count = int(video_reader.get(cv2.CAP_PROP_FRAME_COUNT))

    # Calculate the the interval after which frames will be added to the list.
    skip_frames_window = max(int(video_frames_count/SEQUENCE_LENGTH), 1)

    # Iterate through the Video Frames.
    for frame_counter in range(SEQUENCE_LENGTH):

        # Set the current frame position of the video.
        video_reader.set(cv2.CAP_PROP_POS_FRAMES, frame_counter * skip_frames_window)

        # Reading the frame from the video.
        success, frame = video_reader.read()

        if not success:
            break

        # Resize the Frame to fixed height and width.
        resized_frame = cv2.resize(frame, (IMAGE_HEIGHT, IMAGE_WIDTH))

        # Normalize the resized frame
        normalized_frame = resized_frame / 255

        # Append the normalized frame into the frames list
        frames_list.append(normalized_frame)


    video_reader.release()

    return frames_list

# %% [markdown]
# creating data for the model

# %%
def create_dataset():

    features = []
    labels = []
    video_files_paths = []

    # Iterating through all the classes.
    for class_index, class_name in enumerate(CLASSES_LIST):

        print(f'Extracting Data of Class: {class_name}')

        # Get the list of video files present in the specific class name directory.
        files_list = os.listdir(os.path.join(DATASET_DIR, class_name))

        # Iterate through all the files present in the files list.
        for file_name in files_list:

            # Get the complete video path.
            video_file_path = os.path.join(DATASET_DIR, class_name, file_name)

            # Extract the frames of the video file.
            frames = frames_extraction(video_file_path)

            # Check if the extracted frames are equal to the SEQUENCE_LENGTH specified.
            # So ignore the vides having frames less than the SEQUENCE_LENGTH.
            if len(frames) == SEQUENCE_LENGTH:

                # Append the data to their repective lists.
                features.append(frames)
                labels.append(class_index)
                video_files_paths.append(video_file_path)

    features = np.asarray(features)
    labels = np.array(labels)

    return features, labels, video_files_paths

# %%
# Create the dataset.
features, labels, video_files_paths = create_dataset()
# Out:
# Extracting Data of Class: NonViolence
# Extracting Data of Class: Violence

# %%
# Saving the extracted data
np.save("features.npy",features)
np.save("labels.npy",labels)
np.save("video_files_paths.npy",video_files_paths)

# %%
features, labels, video_files_paths = np.load("features.npy") , np.load("labels.npy") ,  np.load("video_files_paths.npy")

# %% [markdown]
# Encoding and Splitting Training-Testing Sets

# %%
# convert labels into one-hot-encoded vectors
one_hot_encoded_labels = to_categorical(labels)

# %%
# Split the Data into Train ( 90% ) and Test Set ( 10% ).
features_train, features_test, labels_train, labels_test = train_test_split(features, one_hot_encoded_labels, test_size = 0.1,
                                                                            shuffle = True, random_state = 42)

# %%
print(features_train.shape,labels_train.shape )
print(features_test.shape, labels_test.shape)

# %% [markdown]
# MobileNet and Fine-Tuning

# %%
from keras.applications.mobilenet_v2 import MobileNetV2

mobilenet = MobileNetV2( include_top=False , weights="imagenet")

#Fine-Tuning to make the last 40 layer trainable
mobilenet.trainable=True

for layer in mobilenet.layers[:-40]:
  layer.trainable=False

# %% [markdown]
# model

# %%
def create_model():

    model = Sequential()

    # TimeDistributed layer to handle sequences of images
    model.add(TimeDistributed(mobilenet, input_shape=(SEQUENCE_LENGTH, IMAGE_HEIGHT, IMAGE_WIDTH, 3)))

    # Flatten the output of TimeDistributed layer
    model.add(TimeDistributed(Flatten()))

    model.add(LSTM(units=32))

    # Dropout layer to prevent overfitting
    model.add(Dropout(0.25))


    model.add(Dense(128, activation='relu'))
    model.add(Dropout(0.25))


    model.add(Dense(len(CLASSES_LIST), activation='softmax'))

    # Print model summary
    model.summary()

    return model

# %%
# Constructing the Model
model = create_model()

# Plot the structure of the contructed LRCN model.
plot_model(model, to_file = 'model_structure_plot.png', show_shapes = True, show_layer_names = True)

# %% [markdown]
# Specifying Callbacks and Fitting

# %%
# Create Early Stopping Callback to monitor the accuracy
early_stopping_callback = EarlyStopping(monitor = 'val_accuracy', patience = 10, restore_best_weights = True)

# Create ReduceLROnPlateau Callback to reduce overfitting by decreasing learning
reduce_lr = tensorflow.keras.callbacks.ReduceLROnPlateau(monitor='val_loss',
                                                  factor=0.6,
                                                  patience=5,
                                                  min_lr=0.00005,
                                                  verbose=1)

# Compiling the model
model.compile(loss = 'categorical_crossentropy', optimizer = 'sgd', metrics = ["accuracy"])

# Fitting the model
model_history = model.fit(x = features_train, y = labels_train, epochs = 30, batch_size = 8 ,
                                             shuffle = True, validation_split = 0.2, callbacks = [early_stopping_callback,reduce_lr])

# %%
model_evaluation_history = model.evaluate(features_test, labels_test)

# %%
folder_path = '/content/drive/MyDrive/violence_model/'
model.save(os.path.join(folder_path, 'violenceModel.keras'))

# %% [markdown]
# visualizing the output of the model

# %%
def plot_metric(model_training_history, metric_name_1, metric_name_2, plot_name):
    metric_value_1 = model_training_history.history[metric_name_1]
    metric_value_2 = model_training_history.history[metric_name_2]
    epochs = range(len(metric_value_1))

    plt.plot(epochs, metric_value_1, 'blue', label=metric_name_1)
    plt.plot(epochs, metric_value_2, 'orange', label=metric_name_2)
    plt.title(str(plot_name))
    plt.legend()

# %%
plot_metric(model_history, 'loss', 'val_loss', 'Total Loss vs Total Validation Loss')
plot_metric(model_history, 'accuracy', 'val_accuracy', 'Total Loss vs Total Validation Loss')

# %%
labels_predict = model.predict(features_test)
labels_predict = np.argmax(labels_predict, axis=1)
labels_test_normal = np.argmax(labels_test, axis=1)

# %%
from sklearn.metrics import accuracy_score

AccScore = accuracy_score(labels_predict, labels_test_normal)
print('Accuracy Score is : ', AccScore)

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix

ax = plt.subplot()
cm = confusion_matrix(labels_test_normal, labels_predict)
sns.heatmap(cm, annot=True, fmt='g', ax=ax)
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels')
ax.set_title('Confusion Matrix')
ax.xaxis.set_ticklabels(['True', 'False'])
ax.yaxis.set_ticklabels(['NonViolence', 'Violence'])

# %%
from sklearn.metrics import classification_report

ClassificationReport = classification_report(labels_test_normal, labels_predict)
print('Classification Report is : \n', ClassificationReport)
